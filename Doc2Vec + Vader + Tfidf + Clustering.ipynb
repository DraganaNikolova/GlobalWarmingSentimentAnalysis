# %%
import pandas as pd
df = pd.read_pickle("preprocessed.pkl")

# %%
df = df[df['clean'] != '']
df = df.reset_index()

# %%
# Create tfids scores per sentence
# TFIDF
# TF-IDF (term frequency-inverse document frequency) is a statistical measure 
# that evaluates how relevant a word is to a document in a collection of documents.

# This is done by multiplying two metrics: how many times a word appears in a document,
# and the inverse document frequency of the word across a set of documents.

# So, words that are common in every document, such as this, what, and if, 
# rank low even though they may appear many times, 
# since they don’t mean much to that document in particular.
# However, if the word Bug appears many times in a document,
# while not appearing many times in others, it probably means that it’s very relevant. 
# closer it is to 0, the more common a word is. 
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(tokenizer=lambda y: y.split(), norm=None)
tfidf.fit(df.clean)
features = pd.Series(tfidf.get_feature_names_out())
transformed = tfidf.transform(df.clean)
# Out:
# C:\Users\draga\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
def create_tfidf_dictionary(x, transformed_file, features):
    '''
    create dictionary for each input sentence x, where each word has assigned its tfidf score
    
    inspired  by function from this wonderful article: 
    https://medium.com/analytics-vidhya/automated-keyword-extraction-from-articles-using-nlp-bfd864f41b34
    
    x - row of dataframe, containing sentences, and their indexes,
    transformed_file - all sentences transformed with TfidfVectorizer
    features - names of all words in corpus used in TfidfVectorizer
    '''
    vector_coo = transformed_file[x.name].tocoo()
    vector_coo.col = features.iloc[vector_coo.col].values
    dict_from_coo = dict(zip(vector_coo.col, vector_coo.data))
    return dict_from_coo

def replace_tfidf_words(x, transformed_file, features):
    '''
    replacing each word with it's calculated tfidf dictionary with scores of each word
    x - row of dataframe, containing sentences, and their indexes,
    transformed_file - all sentences transformed with TfidfVectorizer
    features - names of all words in corpus used in TfidfVectorizer
    '''
    dictionary = create_tfidf_dictionary(x, transformed_file, features)   
    return list(map(lambda y:dictionary[f'{y}'], x.clean.split()))

# %%
replaced_tfidf_scores = df.apply(lambda x: replace_tfidf_words(x, transformed, features), axis=1)

# %%
df_features = pd.DataFrame(data=[df.clean, replaced_tfidf_scores]).T
df_features = df_features.rename(columns={"Unnamed 0": "tfidf"})

# %%
# Pad tfidf
from keras_preprocessing.sequence import pad_sequences

sequences =  df_features['tfidf']

# Find the maximum length 
max_len = 0
for vector in sequences:
    if len(vector) > max_len: max_len = len(vector) 

print(max_len)
padded = pad_sequences(sequences, maxlen=max_len)
# Out:
# 405

# %%
listPadded = []
for i in range(0,len(padded)):
    listPadded.append(list(padded[0]))

# %%
df_features['tfidf_padded'] = listPadded

# %%
# Doc2Vec
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize

# List of sentences
doc = df["clean"]

# Tokenization of each document
tokenized_doc = []
for d in doc:
    tokenized_doc.append(word_tokenize(d.lower()))

tagged_data = [TaggedDocument(d, [i]) for i, d in enumerate(tokenized_doc)]

## Train doc2vec model
model = Doc2Vec(tagged_data, vector_size = 100, window = 2, min_count = 1, epochs = 100)

# %%
# Load Doc2Vec
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
model = Doc2Vec.load("d2v_model.mod")

# %%
# Add Doc2Vec in df_features
import numpy as np
from nltk.tokenize import word_tokenize

vectors = model.wv
df_features['vectors'] = df_features.clean.apply(lambda x: model.infer_vector(word_tokenize(x)))

# %%
# Add vader columns
from nltk.sentiment import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

compound, neg, pos = [], [], []
for text in df['clean']:
    compound.append(sia.polarity_scores(text)['compound'])
    neg.append(sia.polarity_scores(text)['neg'])
    pos.append(sia.polarity_scores(text)['pos'])
df_features['compound'] = compound
df_features['neg'] = neg
df_features['pos'] = pos

# %%
# Add polarity and subjectivity
from textblob import TextBlob

polarity, subjectivity = [], []
for text in df['clean']:
    polarity.append(TextBlob(text).sentiment.polarity)
    subjectivity.append(TextBlob(text).sentiment.subjectivity)
df_features['polarity'] = polarity
df_features['subjectivity'] = subjectivity

# %%
# Add each in one vector
features = []
for index, row in df_features.iterrows():
    featuresRow = []
    for column in df_features.columns:
        if column == 'clean' or column == 'tfidf': continue
        if column == 'vectors' or column == 'tfidf_padded': 
            for i in list(row[column]):
                featuresRow.append(i)
            continue
        featuresRow.append(row[column])
    features.append(featuresRow)

# %%
len(features[0])
# Out:
# 510

# %%
# CLUSTERING
from sklearn.cluster import KMeans

# n_init equals the lenth of the word2vec vectors
kmeans = KMeans(n_clusters=2, max_iter=10000, random_state=True, n_init=len(features[0])).fit(X=features)
kmeans.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
scores = list(kmeans.labels_)

# %%
negatives = []
for i in range(0,len(scores)):
    if scores[i]==1: negatives.append(i)

# %%
with open('kmeans_negatives.txt','w') as tfile:
    tfile.write(str(negatives))

# %%
import pickle
# Save model
with open("kmeans.pkl", "wb") as f:
    pickle.dump(kmeans, f)

# %%
import pickle
# load model
with open("kmeans.pkl", "rb") as f:
    kmeans = pickle.load(f)

# %% [markdown]
# ### Investigate Kmeans results

# %%
import pandas as pd
df = pd.read_pickle("preprocessed.pkl")
df = df[df['clean'] != '']
df = df.reset_index()
df['prediction'] = list(kmeans.labels_)

# %%
len(df[df['prediction']==1]['text']) # out of 308 371 negative are 28919 ,(76 426)
# Out:
# 28919

# %%
list(df[df['prediction']==1]['text'])
# Out:
# ['RT @__TheCatalyst: Scientists of NASA went to JP Morgan Chase Bank which is known to fund the most fossil fuel projects in the world to tel…',
#  'RT @JunkScience: NYTimes @PaulKrugman:\n\n"Such heat waves have happened before, but climate change has made them increasingly common."\n\nReal…',
#  "@cryptoworld202 You're missing out on $ZRO! \n\nLet's work together to reduce the effects of global warming! With the help of @carb0nfi!\n\nHelp discover a solution to global warming by using your crypto assets! By earning $ZRO tokens, you're helping the environment at the same time!💚 https://t.co/fkR0RKyQcG",
#  'RT @markets: The wonder metal driving the electric vehicle market is in a supply crisis that could hurt efforts to stop global warming (via…',
#  'markets: The wonder metal driving the electric vehicle market is in a supply crisis that could hurt efforts to stop global warming (via @climate) https://t.co/ubem6ibVxh',
#  'RT @BradPorcellato: #NoosaHeads #Georgia #California, Climate Confusion: How Global Warming Hysteria Leads to Bad Science, Pandering Politi…',
#  'The wonder metal driving the electric vehicle market is in a supply crisis that could hurt efforts to stop global warming (via @climate) https://t.co/p85ZGoemKl',
#  'Scientists of NASA went to JP Morgan Chase Bank which is known to fund the most fossil fuel projects in the world to tell people a message on April 6, 2022. | @aryan_ctlyst \n\nRead more:\nhttps://t.co/NZH4F7a8ZO https://t.co/eN9FLhcfF6',
#  'RT @PeterDClack: Be shocked. This is what the global warming scam did to gas prices in the US. Australian power prices have risen 43%. Fuel…',
#  'Bangladesh Confronts Climate Change - book goes open access https://t.co/X5zgf9lYST https://t.co/dowjnig3kr',
#  'RT @FranceinIreland: On 5th November we call all creative citizens w/ practical solutions to fight against #climatechange to join us for a…',
#  'These cities are successfully leveraging #transportation data to take action on #climate change and become more socially inclusive!\n\nShare your thoughts with us using #GMS2018. \n\nhttps://t.co/eYfErbWvlS',
#  'RT @seanroche: One final reminder: if you’re not designing a congestion pricing system to reduce overall traffic volume, you’re practicing…',
#  'RT @Mendelpol: In my first term, I want to solve global warming, end all wars, give a house to everyone, give a job to everyone and England…',
#  'RT @RMetS: Gardening in a Changing Climate - Birmingham 3rd October 2018. Join us for an unique opportunity to hear from scientists and pra…',
#  'RT @mattprescott: New studies suggest France “could easily exceed” 50°C by the end of the century while Australian cities are forecast to r…',
#  "RT @James_BG: This is a sobering read and is well worth remembering the next time the 'let's just adapt to climate change' crowd get their…",
#  '@DrJaninaRamirez What about the totally crazy things people believe now? The Earth is flat. Climate change is a myth. Donald Trump is a good president. Brexit is a good idea...',
#  "RT @FlickRubicon: Surveillance doesn't happen outside of us like nuclear weapons or global warming. It happens inside &amp; between us, to all…",
#  "@jayrosen_nyu It's not only racism and climate change denial that goes together, but also issues such as anti-abortion (or control over women), anti-gay rights and pro-kleptocratic capitalism. Think the root is the wish to enslave others. Climate change is an issue that's really inconvenient.",
#  'Terrifying insights into climate change could build legislative... https://t.co/uutY7qiHcC #ClimateImpacts via @pearltrees',
#  'RT @ClimateReality: #ClimateChange adds fuel to wildfires in the US West by making them more likely and more severe https://t.co/GPChxnNUM4',
#  'seriously stick it Barnaby, it is possible to be trying to buy slightly cheaper clothes for your kid who grows outta them in 3 months and still give a shit about climate change. don’t insult people’s intelligence. https://t.co/2Xkfep28CN',
#  'RT @PsychopompGecko: Jordan Peterson, with Koch backing, went from an anti-trans activist to an influential speaker teaching so-called skep…',
#  'Good \u2066@scottishlabour\u2069 backs net zero by 2050 at latest target in Climate Bill as \u2066@sccscot\u2069 calls for &amp; Just Transition Commission in Bill, on statutory long-term basis as JTP wants. #justtransition \u2066@ScottishTUC\u2069 \u2066@claudiabeamish\u2069 https://t.co/r4jaREn1O4',
#  'RT @Richard_Dixon: Shell\'s 50th - 50 years of climate change denial https://t.co/KCjbLOd98F  "The planet cannot afford to have Shell still…',
#  'Helder en lezenswaardig stuk over de relatie tussen bosbranden en #klimaatverandering. \n\nBosbranden worden - al dan niet opzettelijk - veroorzaakt door menselijk handelen; risico op snelle &amp; wijde verbreiding van het vuur neemt toe door klimaatverandering https://t.co/LGR83piFFx',
#  '@FoxNews @dbongino Trump’s “winning”\n\n-TaxScam wasn’t for the middle  &amp; gov’t cannot afford it\n-Stagnant Wages\n-ICE now a secret police, taking away from all the good they do.\n-Blind eye to Climate Change\n-Turn the World against us\n-Divide America\n-Tariff damage \n-Racism\n-No economic credit for 44',
#  "Trump reignited his war with California, but his Tweet got burned\n \n@dana1981 article about the evidence of #ClimateChange causing more #Wildfires in #California highlights the #stupidity of the current #US administration, – especially @realDonaldTrump's \nhttps://t.co/2JjGZf6fPP https://t.co/eyKNMMbUne",
#  "RT @Bidge3: @billatnapier More #BBCbias all in the name of establishing a false #balance amongst #experts. When 'too many others putting th…",
#  'Living on a red hot planet will challenge everyone and everything to the brink 🔥 act on climate change now! https://t.co/bayrKo7i7M',
#  'I think this was the intention all along. Maybe it is time to stop depending on "Washington" to babysit us our whole lives and start taking initiative. Americans have great advantages and a low tax burden. Go be the change you wish to see in the world. https://t.co/eFLbs6bqdB',
#  'RT @DonnaBow: Business leaders are increasingly united behind a #netzero emissions target by 2050, says @ClimateCLG. https://t.co/y4oDZlfUV…',
#  'RT @unisonscot: Good \u2066@scottishlabour\u2069 backs net zero by 2050 at latest target in Climate Bill as \u2066@sccscot\u2069 calls for &amp; Just Transition Co…',
#  'RT @MagikMilly: @SkyNewsAust @JohnAndersonAO And our current government is doing everything in its power to drag us back 60+ years, to a pe…',
#  'Decarbonization is moving far too slowly and certainly slower than it must to avoid and ensure that we stay well below the predicted 2C increase in global #temperature rise. #HeatWave2018 #climatechange @ArekSinanian https://t.co/lHpakzX27O',
#  'I Challenge benshapiro to a debate on climate change. Lets see him defend his ridiculous argument on CNN against me. Debate me at CNN Studios. Dont worry, Im kinda sure I can get CNN Studios to host the debate. Ben is afraid. https://t.co/PZAbbz1YBH',
#  'What will the effect of global warming be on your business\nHow can you Future proof now?\nSign up to our mailing list to get this two part Global Megaforces Energy Factsheet.\nWe will send them to your inbox for FREE. \nhttps://t.co/fsFAlX8lCZ #Mind-The-Gap-Mondays',
#  'Call For "Organizing Committee Members"\nWorld Congress on #Geology &amp; #EarthScience which is slated to hold from July 11-13, 2019 at #London, UK.\nFor details, PS: https://t.co/w3dCIMYlHB\nBecome a #Organizing member, Kindly mail us at geology@iicpl.org\n\n#geoscience #climatechange https://t.co/ebkZJTDQNM',
#  'The latest Guns in America! https://t.co/sksM7SZWdE Thanks to @dihoppy @CopperBronzed @sergei521 #blacklivesmatter #globalwarming',
#  'RT @ProfBarbaraN: Living on a red hot planet will challenge everyone and everything to the brink 🔥 act on climate change now! https://t.co/…',
#  'RT @RnfrstAlliance: 73% of Americans believe #climatechange is real--the highest number ever. https://t.co/hmYQAGQzqB via @grist',
#  'RT @PaulEDawson: "..as early as the mid-1960s, [they] planned their own business operations around rising seas &amp; other harms from climate c…',
#  'RT @AmyAHarder: Important quote on climate change from former coal mining group official: "It\'s too late for denial when your customers, th…',
#  'RT @ofthesparrows: boris with his tea-tray? DON\'T WASTE MY TIME. US congressman bringing snowballs to work to "disprove" climate change? DO…',
#  'Learn how to tell stories that spark the kind of social learning needed to put us on the path to a resilient food future. .Weekend course with @resilientag  Laura Levnick @SchumacherColl #foodculture #resilience #climatechange https://t.co/neKSA9YdVV https://t.co/msFJ7XiVPT',
#  'RT @physicspolitics: Macron:"There is no Planet B.On this issue We have a disagreement between the U.S. &amp; France But that is a short-term d…',
#  'AI takes a deep dive into the oceans, allowing scientists to uncover the true impacts of global warming while helping to develop more efficient research methods https://t.co/EpWN8T7lI8 via @Guardian #AI #Science #GJENews',
#  "So basically if wars and all the issues we have don't end us, global warming will🎊",
#  'RT @Connect4Climate: .@LowCarbon_City competition #ShowtheChange: Impacts and Solutions for Climate Change is back! 500 euros to be awarded…',
#  'RT @nathanpboston: .@SpeakerDeLeo &amp; @jeffrey_sanchez tried to slow down our clean energy transition as much as they could get away with, bu…',
#  '@plbrocks @NJL1980 If the NEG goes down remember this "I will not lead a party that is not as committed to effective action on climate change as I am". Tomorrow is the last chance.',
#  'RT @ECVC1: "The EC does not seem to have realised the seriousness of the challenges  facing the planet in terms of the environment, climate…',
#  'Richmond Fed,  "[However,] rising temperatures could reduce overall growth of U.S. economic output by as much as one-third by 2100." #climatechange \n\nRecord-high temperatures could scorch U.S. economy - CBS News https://t.co/yV63SAQAEp',
#  "I watched First Reformed last week and I cannot stop thinking about how it is now possible to mine affecting, resonant drama out of the certainty of climate change catastrophe. it's no longer science fiction.",
#  'Time for action Mr. President @realDonaldTrump I know you think NBC is a fakenews channel but look who are all backing up this story. \nIt’s time to do something and with your influence in the world it would be great if you stand actively by our side. Thanks. #climatechange 💚 https://t.co/2NFlPs0Uug',
#  '@Conservatives you must be so proud of your "conservative values". "What do it donors want us to do?" https://t.co/5uO3bpje8Q',
#  'RT @aDissentient: Suddenly, as if by magic, global warming promoters decide that weather events tell us nothing about climate. https://t.co…',
#  'RT @Babs73561697: @armyxculture @BTS_twt I’m curious about environmental awareness. I see many social topics being discussed but not a lot…',
#  "@WyssFoundation @HOMMENVIRONMENT @AP This is bad news!! With them, [ the loss of the Baobob trees], will go centuries of tradition, necessity and beauty... Let's wake up peeps: Climate change is REAL! HOW MANY MORE WARNINGS WILL IT TAKE?",
#  'RT @jvcdelaney: #Competition #Biology #STEM #GirlsInStem #Climatechange #coloring #colouring #Freebie #MondayMotivation #sciart https://t.c…',
#  "@annajhenderson @politicsabc People in K-Mart don't care about #Joyce, his book, his debacle of a private life...they do care about honesty, integrity, #rorting the system with OUR tax $$$...AND a future on this planet!! #environment #climatechange https://t.co/f4OKKqx45f",
#  'RT @thierry_bros: I completely disagree. Germany has a non-EU climate unfriendly energy policy and this task force is not going to change a…',
#  'There is No Planet “B”! There is No where to hide! God gave us a Job to care and protect the Earth, we are failing. The Billionaires will be the last to go hungry when food won’t grow, fresh water is scarce and the Land is dust. #ParisAgreement #EPA #FollowMe @ClimateReality https://t.co/YY0xffJbVo',
#  "Christian 'dominance' will die. And rightly so actually. Secondly, Paganism is relevant to the times we live in, in that it reveres nature and natural forces, and that is important at a time when lack of this has given us climate change and rampant pollution (3)",
#  '#auspol the climate change emergency has hit critical. If our leaders aren’t doing anything meaningful or actively blocking immediate, necessary action, should we be letting them lead us off the cliff while saying ‘don’t worry, it’s all a hoax’. We’re witnessing abliteration. 😰',
#  '.@RichmondFed says #record #heat &amp; brutal #winters, #weather swings widely understood to be the result of #ClimateChange, are likely to have a huge #negative impact on the #US #economy, reducing #economic growth.    https://t.co/6f7qR2WMWb',
#  'RT @CharlesBullar: There is No Planet “B”! There is No where to hide! God gave us a Job to care and protect the Earth, we are failing. The…',
#  'So solar geo-engineering is not going to save us from the worst effects #climatechange, it seems - a new paper in @nature suggests its consequences will override its benefits. Sorry to be a Debbie Downer https://t.co/ZVeRxmf6v2',
#  'New world order con la scusa del #climatechange  niente di nuovo sotto il sole. https://t.co/07SLAjYTUI',
#  '@KateEmerson88 Keeping all my fingers and toes crossed that we will get a good drenching soon, Kate. It’s hard enough trying to keep a garden going, but all I can think of is our farmers and our beautiful wildlife trying to survive. Damn this climate change, damn our apparent apathy towards it',
#  'Instead we have a national public broadcaster giving climate denying lying luddites a platform. What happened to truth and facts #abc730? https://t.co/dcjFfOeWFm',
#  '@kimberlyn2117 @katat525 @francie413 @kstortenbecker @ericbolling @Pataltschul @ShepRose @Andy @Bravotv Wait, are you talking about children being removed from parents and put in cages?  Because that’s what I thought the rest of us were talking about.  As well as the reversals on asbestos, endangered wildlife, and climate change?  This is all pretty new.',
#  'When they look through a school and see outstanding curriculum, teaching and learning, climate, behaviour etc and they can’t understand why the results aren’t high, they must conclude the provision outstanding despite outcomes. Not going to happen me thinks. https://t.co/GRoUEGKJ2P',
#  '"You don’t want to be the last one that wants to get out of certain assets once you realize they are no longer viable,” How companies are pushing ahead on climate change: https://t.co/QiBxiT8pgB',
#  'India needs to ensure greater coordination in electric vehicle deployment: 13 August 2018, Sweetcrude, Lagos — As the world approaches peak oil and starts witnessing the consequences of climate change, electric vehicles (EVs) have emerged as an… https://t.co/ia6LTmSu0Q',
#  'RT @dwallacewells: "In an extraordinary event for the world’s highest peak, rain and snow are falling on Mount Everest this summer at twice…',
#  'Mojave Desert birds crashed over the last century due to climate change #nature Wish a beautiful week ahead',
#  '@KeiraSavage00 It would actually have a negative effect, as we de-industrialise our nation, sending production and jobs offshore to third world countries that care little for pollution or climate change, the environmental damage will be exponentially worse... 😠',
#  '@JosephTracey4 @UWEair @globeandmail @globepolitics Climate change is natural, but influenced by human activity. That’s the part we need to change. We created the increase in 400ppm carbon &amp; temperature increase by 1.5 C. That’s the part we need to moderate &amp; slow. Cost of doing nothing is huge already!',
#  'RT @hurst_sj: So solar geo-engineering is not going to save us from the worst effects #climatechange, it seems - a new paper in @nature sug…',
#  'As we see the impact of climate change play out in real time around us, we might do well to shift the conversation away from arguing with those who maintain that the phenomenon does not exist. https://t.co/bmCL5KY1ls',
#  'RT @EU_H2020: "The loss of an ancient monument is a loss for us all" What\'s #ClimateChange doing to our most beloved structures? HERACLES m…',
#  '@IOL Important to realize the environmental conditions behind this story and pay attention to the patterns, which may be resulting from #climatechange',
#  'RT @veganfuture: Going Vegan to Combat Climate Change https://t.co/33YZuDv8SS',
#  'Innovation for Sustainable Development Hackathon Event #Green #Power #Water #ClimateChange https://t.co/5uYEQnDaJp. To join the team, email us here: telecoms@skylinemarketingsolutions.co.uk https://t.co/yMcdI0EhbC',
#  '"Pacific countries may set up huge climate change fund. The Pacific Islands Forum summit in Nauru next month will consider the region pooling resources to create a US$1.5 billion climate change fund." https://t.co/amNO2WOG5N',
#  'NO. And you’re exploiting extreme misery on top of it. MONSTER. #ClimateChangeIsReal  https://t.co/SY6wRdEIOQ',
#  "#pmlive Why'd LNP BASE vote 4 Mal when just like ALP he'll elevate electricity prices with less tax cuts-We hate ALP green policy but LNP=just as bad without the bigger personal tax cuts-So if both party's shaft us with climate change-basic personal economics=why pick LNP🤷\u200d♀️",
#  "RT @ClimateReality: First things first – let's get the facts straight about climate change https://t.co/0303bwcJSH https://t.co/haNeghDnxX",
#  '@jofo2005 @globeandmail @globepolitics There is no common sense anyone can attach to climate change &amp; global deniers. Just stupidity!',
#  'RT @samanfarid: 1/2 This incredible article outlines one of the biggest challenges humanity has faced — the most visible of many “planet-sc…',
#  'Breaking it down:\n\n“We have these large undulations in the jet stream. And that gives us extreme weather. But what’s also happening is that the jet stream isn’t moving them along. We... https://t.co/0R7Qb8hOJa',
#  '@KKeneally Yep and for @Barnaby_Joyce benefit I was with a couple of dozen people at a local pub and everyone of us cared about #climatechange and were furious about the #GBRF \n#auspol',
#  'Williams’s battle cry -- don’t blame us, blame climate change -- is catching on. PG&amp;E’s neighboring utilities, Edison International and Sempra Energy, are echoing the defense, and it may well serve as a blueprint for ...',
#  '@RudyGiuliani Trump’s “winning”\n\n-TaxScam wasn’t for the middle  &amp; gov’t cannot afford it\n-Stagnant Wages\n-ICE now a secret police, taking away from all the good they do.\n-Blind eye to Climate Change\n-Turn the World against us\n-Divide America\n-Tariff damage \n-Racism\n-No economic credit for 44',
#  '@simonahac @EuanRitchie1 It shouldn’t just be about the dollars.  For many households $550 per year saving will not be noticed.  For those where it makes a difference they need support. All of us need to think about climate change',
#  "@TonyAbbottMHR @CraigKellyMP @Barnaby_Joyce @GChristensenMP @The_Nationals If Mal's energy policy=as bad as the ALP but they give us bigger personal tax cuts which helps every family bottom line WHY WOULD ANY1 VOTE 4 THIS REPTILIAN FABIAN SOCIALIST MASQUERADING AS AN LNP LEADER? https://t.co/2ZRUlIgFHl",
#  "Like I'm going to believe the DC power outages were for climate change awareness. Haha. \nWhoever came up with that headline is brilliant though lol.",
#  "RT @Dave_Chadwick_: 'Climate Smart Agriculture Wales' survey for red meat and dairy farmers is live! Tell us of what you think of proposed…",
#  '@samidimassi_UN @UNEnvironment @UNEnvironmentAR Totally agree, yet this sector is one of the climate change adverse contributers, consider friendly refregrants, energy effeciency and life cycle. A shift tward natural heating and cooling designs of cities and buildings would be a way to consider',
#  'Save the Grouse. Save the Harriers. Save all wildlife. Save us from everything bad , from Climate change, polluted seas etc. But FIRST OF ALL, save us from BORIS becoming Prime Minister. McEnroe said it "You cannot be serious".To Boris ,or Britain?',
#  'RT @simonahac: 👓 please, take 30 seconds to study this chart to realise just how utterly pathetic @TurnbullMalcolm’s #NEG emissions target…',
#  'Innovation for Sustainable Development Hackathon Event #Green #Power #Water #ClimateChange https://t.co/IH8SD67UM6. To join the team, email us here: telecoms@skylinemarketingsolutions.co.uk via @Enzen_Australia https://t.co/fKdZwXYrVb',
#  'RT @BillOddie: Save the Grouse. Save the Harriers. Save all wildlife. Save us from everything bad , from Climate change, polluted seas etc.…',
#  'RT @freeksels: Vandaag 50 jaar geleden begon Shell met oliewinning op de Noordzee. 50 jaar geleden wist Shell ook al dat dat klimaatverande…',
#  "@jeffpearlman No, sir. The biggest problem you have is that you have a Leader who doesn't believe in climate change. It stunts your country's collective power to fight it. The world is looking up to America... but the emperor is concerned more on his businesses than his people and the planet.",
#  'RT @GreenpeaceNZ: From California to Japan, climate change is clearly on the march https://t.co/oh8jwadzqh via @SCMPNews',
#  '@AngelaKorras We’re getting older and more susceptible to extreme weather. Our generations will probably pay a heavy price to climate change (which they failed to curb) in their golden years.',
#  'What can pigs teach us about climate finance? As journalists at our training course in #Vietnam found out, where there’s muck there’s money.  🐷💵\n\n#Climatechange @SNVworld @SNVVietnam\n\nhttps://t.co/fLSXgDLKMr',
#  'RT @GermanEnvAgency: Would more #climateprotection be so bad for the world? We agree with German comedian Marc-Uwe Kling. By the way: #Clim…',
#  '@JonC54 #climate\n\nSounds like we will need to live in domes or something. Horrible that anyone in this day and age still denies climate change. Humans have done no preparations for this at all.',
#  'Journalists and inhabitants of planet earth: don\'t forget to keep track of our indispensable series "This month in #climate science" #climatechange https://t.co/JrHQc3P6nx',
#  'Climate change could kill us all off.\nDoes the hard right not understand the precautionary principle #QandA',
#  'RT @robin_willing: Lets hope that the "Commission for Exiting Coal" can do just that ~ Germany’s #coal task force can change things for Eur…',
#  'RT @wrieurope: Journalists and inhabitants of planet earth: don\'t forget to keep track of our indispensable series "This month in #climate…',
#  '@PaulWheelhouse Hi Paul! You+@Claudiabeamish shld chat! My understanding - they are being guided by top down science on #climatechange, clear need 4 targets 2 signal change across whole economy so transition can be managed fairly and to drive innovation in every sector.',
#  'RT @vicfoldrecycler: #MondayMotivation In the words of Former US President Jimmy Carter "#SolarEnergy will not #pollute our air or #water,…',
#  '@QandA Sadly Eric and his elder statesmen will be dead by the time climate change bites us all!',
#  'RT @clemetivier: #Fossilfuel companies try to label coal, oil &amp; gas as "solutions" to end energy poverty in a new campaign.\n➡️Don\'t let thi…',
#  "Lucky (?) we've got global warming to keep us warm, shame about wanting to get cool #qanda",
#  'RT @TR_Foundation: What can pigs teach us about climate finance? As journalists at our training course in #Vietnam found out, where there’s…',
#  'By 2100, 970 cities will experience *average* summer temperatures over 35C, and dozens will regularly top 50C, including, "easily", Paris #climatechange #hothouseearth https://t.co/rD5aTnvN6L',
#  'Considering the climate change, we’re gonna go to Martin Garrix and Skrillex concerts on the warm beaches of Alaska and Russia in just some decades. Cool, let’s start booking! 🏖🎇\n\n #climatechange #globalchallenge #russia #alaska #GlobalWarming',
#  'RT @JulianBurnside: Climate change could kill us all off.\nDoes the hard right not understand the precautionary principle #QandA',
#  'RT @patrickgaley: By 2100, 970 cities will experience *average* summer temperatures over 35C, and dozens will regularly top 50C, including,…',
#  'the scale of the catastrophe that awaits us will soon become obvious\n\n"almost without exception. every single time we\'ve covered it\'s been a palpable ratings killer. so the incentives are not great." -@chrislhayes\n\n#ActOnClimate #HeatWave2018 #Drought\n\nhttps://t.co/vEjDrXop4e',
#  'Files under "Stuff my sis-in-law says."\n\nShe truly believes most of us will be dead from some version of "sweating sickness" within a decade. https://t.co/5Hhjd5eVgd',
#  'It is time for Americans to demand leaders who understand climate change and have the will to deal with it. Glacier National Park is now burning. @realDonaldTrump &amp; his Admin has its head in the sand. Enough. #VoteThemOut #ClimateChange',
#  "@bkbaguley @abc730 In the interests of balance could we please have @AdamBandt to give a contrary voice to @TonyAbbottMHR &amp; the NEG debate #QandA I can't believe that you claim to be fair &amp; yet give no voice to #Globalwarming science",
#  '#Brazil cut its GHG emissions from deforestation in 2017 to levels that meet its 2020 #climatechange targets by cutting 610 million metric tons of CO2. Amazon &amp; Cerrado, are seen as vital in fight for the #climate\n\nhttps://t.co/8TeVX7ggaU',
#  'Good to see a #refugee taking a stand for #climate action! Meet the young refugee behind #ZeroHour’s climate platform https://t.co/DL6NEEXQb3 via @grist #climatechange #activism #immigration',
#  'A Changing Climate Gives Us a Chance to Change the World https://t.co/Avb8j2Mi8g',
#  'All time heat record in @GlacierNPS \nThis is #climatechange in action melting the Beautiful Glaciers.\nMake Plans to visit soon before they are all melted.\n#FindYourPark https://t.co/jnVIJETfJ5',
#  "Not even talking about the #TradeWars already under way....\n\nLet's review Trump's Fart of the Deal: https://t.co/6PsD2kPKuK",
#  '#QandA The debate on what science suggests is the existential threat of continued, cumulative &amp; ramped-up greenhouse gas is reduced to a discussion of current power costs. What is the Australian economic modelling of the future economic costs to us of  unmitigated climate change?',
#  "If it was not for CO2, we would not be discussing it today. What Concentration Does #CO2 Become Toxic To Humans? 'Did you know that every time you cut the grass in your garden you generate over 10,000 PPM of CO2!!!' https://t.co/Wlmghtj6kx #AGW #ClimateChange https://t.co/cvIViFLB18",
#  'RT @drcwhos: @bkbaguley @abc730 In the interests of balance could we please have @AdamBandt to give a contrary voice to @TonyAbbottMHR &amp; th…',
#  "Dimanche 12 Août 2018, en prélude à la journée Internationale de la Jeunesse, a eu lieu le lancement du projet Vol-Eco au CEG 1 de Parakou\nCe projet est une initiative du mouvement FUS qui prend en compte les problèmes l'environnementaux et écologiques #ClimateChangeIsReal https://t.co/MZhj54cBKc",
#  'Latest MedicineNet News Study Forecasts Dramatic Floods in Western U.S. Barriers to Doctor-Nurse Communications Legalization of Same-Sex Marriage Fatty Fare a Fave for... https://t.co/d3zC7C4AXX',
#  '@QandA @SenatorAbetz @CornelWest The clear consensus about the destruction global warming will wrought are not brave predictions but scary facts. @senatorAbetz clearly deluded and still unwilling to admit his business pals’ profits aren’t more important than planet Earth #QandA',
#  "Because the prospect of #sealevelrise #drought emerging diseases, resource wars and crop failures isn't scary enough, let's think about how awful it will be when increasing numbers of people are just way too hot https://t.co/a19IhMzQ79 #climatechange #mondaymorning #ohshit",
#  '@andrewdamitio "Deconstructing the administrative state," which is going to be one of the most damaging and lasting legacies of this administration. It may even end the human race because of unchecked climate change.',
#  'RT @NayukaGorrie: Hello is anyone linking this drought stuff to climate change? I’m hearing things about farmers wanting long term solution…',
#  "Climate change is real. Let's change our attitudes towards pollution to make a better and beautiful earth 🌍 for longevity of life. https://t.co/uaB0Gn5W4z",
#  "We've launched a new Award for 2019 - Cooling for People. If you know of any cool initiatives that should apply, send them our way! https://t.co/WmM1TSDExr #CoolingforAll #FurtherFaster #SDG7 https://t.co/yeCIS1XSaD",
#  'RT @IOM_MECC: Every year 𝟮4 𝗠𝗜𝗟𝗟𝗜𝗢𝗡 𝗣𝗘𝗢𝗣𝗟𝗘 are forced to move because of #disasters and countless because of #climatechange. Here is how th…',
#  "RT @Shareblue: In a desperate attempt not to acknowledge climate change, the Trump team is blaming 'radical environmentalists' for the dead…",
#  '#QandA One of the scary things about trump is that the very people who are still being exploited in the US (those working 2 jobs &amp; still not making ends meet) is that he duped these very people in voting for him. #ClimateChange will adversely affect the poorest among the world&amp;US',
#  'We should be #leadingonclimate given our natural resources, but instead the Libs are determined to take us back to the 19th Century with their focus on coal. #qanda https://t.co/ik6xMPD77o',
#  'Y ya puestos al tema, podemos ir directamente a la fuente de la advertencia, World Scientists’ Warning to Humanity: A Second Notice | BioScience | Oxford Academic https://t.co/OKgD6staoV (hay en esa misma web una versión en español).- #climatechange',
#  'If food waste were a country, it would come in 3rd after the US &amp; China in terms of #GlobalWarming impact! To find out how you could reduce your business food waste call us today! @washingtonpost    \nhttps://t.co/nacv5g15Vm',
#  'Please join us on 22 January for the start of the hearing &amp; show your support here! #InMyName https://t.co/1umWyrK1af https://t.co/iTAOMPsy7W',
#  'RT @ScheuerJo: Leading scientists warn that passing such a point would make efforts to reduce emissions increasingly futile #climatechange…',
#  "RT @BlaineBershad: Not even talking about the #TradeWars already under way....\n\nLet's review Trump's Fart of the Deal: https://t.co/6PsD2kP…",
#  '@djennison @craigthomler @davidsirota The EPA needed gutting, most regulations do nothing but choke growth, Paris was a joke, and I think coal jobs are more important than some Malthusian democrat dinner party nonsense. The market will solve global warming.',
#  'RT @climatecaseire: Please join us on 22 January for the start of the hearing &amp; show your support here! #InMyName https://t.co/1umWyrK1af h…',
#  '&lt;13% of #wildfire stories from  top US news outlets mention #ClimateChange, according to survey from Public Citizen, including only 11% of TV segments &amp; &lt;10% of stories in #California newspapers\n\nThis is missed opportunity for real #climate education\n\nhttps://t.co/aQa1i9pXLF',
#  "RT @FdnCarmignac: Where in the world is @mediakadir? We can't disclose too much information, but the 9th edition laureate did send this hap…",
#  'RT @EDFtx: New study: Texas would lose about $100 *billion* in GDP because of climate change.  https://t.co/Odstc2NirY',
#  "RT @NopiaRide: Sooner or later, we will have to recognize that the Earth has rights too. To live without pollution. Let's take good care of…",
#  'RT @Greenpeace: Climate change isn’t just affecting polar bears. It’s affecting us all. https://t.co/50ZAjrVBms',
#  '#California First to Sign #GreenBond Pledge to Fight #ClimateChange https://t.co/1CpMT6Rjzu via @Global Ethical Banking',
#  'RT @NLinAustralia: Scientists warn a “Hothouse Earth” is irreversible if the world warms up by 2°C. Among them are #Dutch and #Australian r…',
#  'RT @tan123: Penn State #ClimateScamBS: "Lancaster County’s dairy farmers could be facing devastating drops in corn yields by 2050 because o…',
#  'We consider Ireland’s performance on mitigating climate change via the energy sector. Data suggests it’s a case of some movement in electricity but a clear need to step up action @EPAIreland https://t.co/1CsZsOopH1',
#  '@D_LittleproudMP @The_Nationals Unlike rich Farmers, ordinary Aussies don’t own $multimillion assets, we don’t have unfair political power &amp; we don’t vote for climate change denialists then expect a handout when the drought comes, but can we also please get massive welfare handouts when things go wrong for us? https://t.co/qQpzV9UKno',
#  'RT @GRI_LSE: Most of the top global companies in the electricity, coal &amp; oil &amp; gas sectors have yet to adopt business strategies that align…',
#  '@oldbaldgit @jonusher @NBristolSusCom @WestofEnglandCA @transportgovuk @HighwaysSWEST and let\'s get a little "eco" here. Driving is one of the biggest impacters of climate change. The toll should stay and subsidise train travel between Wales and the West of England. Congestion costs the west of England £500M per year.',
#  '"Hell Is Coming For US"\n\n#ClimateChangeIsReal #ActOnClimateChange #ThereIsNoPlantB https://t.co/QlhrCcynaL',
#  '"Imagine a city at 50C (122F). The pavements are empty, the parks quiet, entire neighbourhoods appear uninhabited. Nobody with a choice ventures outside during daylight hours. Only at night do the denizens emerge, HG Wells-style, into the streets..." #ActOnClimate https://t.co/fER00ixNc0',
#  'RT @IIGCCnews: Germany’s #coal task force can change things for Europe https://t.co/9ZsQsqkw8Q via @financialtimes #ClimateChange',
#  'RT @MotherNatureNet: This tiny fern could help us fight climate change https://t.co/0gM9Kg96l3 https://t.co/G1mVHMY7aW',
#  'RT @Jim_Pembroke: @annajhenderson @politicsabc Went to Kmart and bought some SPF 50 sunscreen $4.00\nCoz if people like Barnaby Joyce are ru…',
#  "@AodhBC @creedcnw Not really. Ireland is 2% of EU Agri trade. Assuming that a) carries weight and b) expecting preference or bias or favours shown when EU represents all isn't realistic. E.g EU could bail out Irish Agri for poor mgmt but won't, as others have managed climate change &amp; growth.",
#  'With all that’s happening around us, It’s hard to believe that there are still people who don’t believe in climate change and that there are still many who don’t care. 🤦🏻\u200d♂️',
#  "ANDREW BOLT: “I have a message to the @LiberalAus MPs - why don't you finally get the guts to make a stand against your Prime Minister's global warming idiocy? Do it before he leads you over a cliff.” \n\n#StopTheNEG #BringBackAbbott #pmlive #auspol https://t.co/8CWEaAupja",
#  '2 things. 1, 2050 represents a slowdown in action. 2, Agreeing a target is one thing but agreeing HOW to meet it is quite another. https://t.co/vDRMUbHl1A',
#  '@juliana6878 @ozipetezar @TurnbullMalcolm Or us as we stand by watching the world implode from over population, environmental plundering and our own man made climate change.',
#  "@GreenNewsDaily US Refineries runningAt\nnearRecordHighs.\nhttps://t.co/KnKoCJltcR\n@EricHolthaus\nUnlessWeSidelineMuchOfThe\nworld's Gas&amp;Oil&amp;Coal reserves,\nwe'llSidelineOurWellbeing,\n&amp;AbandonTrillions$$$inRealEstate.\nEveryBitExtracted&amp;PutInPipelines\nguaranteedToBeBurned.\nhttps://t.co/Ng8gZYtg4S",
#  'Here we go again: "US fossil fuels target global energy poverty, climate change in new PR push" https://t.co/quT8LJhM8u\n\nIt\'s @peabodyenergy\'s BS "Advanced Energy For Life" (@AdvancedEnergy, defunct &amp; rebranded) once more. \n\nhttps://t.co/V3K4N399MZ #Coal #BeyondCoal #astroturfing',
#  '@CitznOfNowhere @geralltg Patriotism is wanting you country to be well, be safe, be healthy &amp; have cohesive communities, not starving public services, having poor pensions, defunding NHS, privatising for profit, demonising taxes as negative, ignoring air pollution &amp; climate change warnings.',
#  '@OzEquitist That sounds like the Liberals. Putting Boomers before an agreement that will keep the future generations from having to deal with a destroyed environment and unbearable climate change effects. Thanks, pricks.',
#  'RT @WRIClimate: Clear, robust and cohesive implementing guidelines set cycles of #ParisAgreement in motion to achieve #zero-carbon emission…',
#  'RT @_Fever7: North Korea is stockpiling nuclear weapons, Iran is planning cyber attacks against us, global warming is almost at the point o…',
#  'RT @ChesterEnergy: &lt;13% of #wildfire stories from  top US news outlets mention #ClimateChange, according to survey from Public Citizen, inc…',
#  '"When taken together, the world’s top five meat and dairy corporations are already responsible for more emissions than ExxonMobil, Shell or BP"\n\nWe need to change our privileged lifestyles and do whatever it takes to reduce our GHG emissions to zero NOW. https://t.co/VbxjWZnzkk',
#  'RT @GChamberlainAZ: What are criminal capitalist doing in response to #climatechange destruction ? 195 national gov , 13 U.S. state gov nea…',
#  'When global warming sees us all decamp to Mars, we could be housed in comfy 3D printed, locally sourced pods #ribajproducts @AI_SpaceFactory\nhttps://t.co/2XAzqNa1FT https://t.co/6dD0KHBool',
#  'RT @sunitanar: Extreme Is The New Normal. Lets get real. Pl. see and share this infographic on our #climatechange risked world https://t.co…',
#  "'What's important is we manage our forests' - what a pathetic statement. What's needed is a World #Deforestation Ban Treaty. https://t.co/8jx8XQMHmW",
#  "RT @PaulBarasi: 'What's important is we manage our forests' - what a pathetic statement. What's needed is a World #Deforestation Ban Treaty…",
#  'RT @angrynationalis: @DavidCampbell73 #auspol #AltRight Indeed, Tony is not a scientist however  I majored in #biology / #earth science &amp; a…',
#  'RT @Alex_Kump: "if you can\'t accept that Musk is trying to save the planet from global warming by hastening the extinction one of the two b…',
#  'RT @FoEint: We’re already feeling #climatechange impacts, but a new study in @PNASNews warns we could be heading towards a #HothouseEarth\nW…',
#  'RT @COP23: 2018 is the year of #Talanoa4Ambition. Follow us to join the global conversation on progress in the battle against #ClimateChange',
#  'TODAY @ 1pm ET: Briefing for reporters on the state of science linking climate change to wildfires, extreme heat,  floods. You can still register (media only): https://t.co/jPRhUGIApE',
#  'RT @RealSciLine: TODAY @ 1pm ET: Briefing for reporters on the state of science linking climate change to wildfires, extreme heat,  floods.…',
#  'This is the best thread I have read that explains how climate change will and is impacting us.\n\nPlease read and share this. https://t.co/MNnao19wNO',
#  "If anyone is wondering why my earlier post about #climatechange and #heathealth in cities caused me to be so worried about my dog's paws, here is a picture of her from this morning.\n\nTry not to fall in love with her. \n\nJust try. https://t.co/YcNQppUJ3X",
#  'RT @LeoHickman: In January 2007, the BBC aired a special programme presented by Sir David Attenborough called "Climate Change - Britain Und…',
#  'RT @RedTRaccoon: This is the best thread I have read that explains how climate change will and is impacting us.\n\nPlease read and share this…',
#  'RT @DoctorVive: 1 Canada got really, really hot\n2 The Arctic caught fire\n3 A mountain shrunk\n4 Rare bacteria became plentiful\n5 Lost societ…',
#  'From @Reuters — CO2 emissions make the planet greener, the @UN puts out fake science about climate change to control the global energy market, and wind and solar energy are  "dumb," were among the messages of the America First Energy Conference. https://t.co/qkExTheKuh https://t.co/TPaeT55tPu',
#  'The emergence of a mature timber asset class may lead managers towards conservation strategies. This includes the sale of carbon credits to provide additional revenue streams. #climate https://t.co/nGs0mSmTKb',
#  'In #laudatosi @Pontifex calls on us to hear the cry of our poorest brothers and sisters in the global south who suffer most from climate change. Great news that @scottishlabour have committed to supporting net zero emissions by 2050 in the new Scottish climate bill https://t.co/HaoqvzJ0nL',
#  ".@NYSERDA has committed $20.5M to #StonyBrookU's Advanced Energy Research and Technology Center, following a $18.5M @ENERGY grant. The #AERTC will be a hub for #CleanEnergy #research. https://t.co/DFVHvecJkj #Innovation #ClimateChange @CEASSBU https://t.co/BfsDpwN1LA",
#  'Canadian taxpayers give away millions to US pipeline owners, despite threat to #GlobalWarming and #foodsecurity https://t.co/ZGhXCStbvP',
#  "RT @BNerlich: Last call-out for my reflections on the 'hothouse earth' metaphor https://t.co/vsGtGITdDF #climatechange #hothouse #metaphor",
#  'RT @LeroyWesterling: We are not, and will not, experience a “new normal” of wildland fire behavior. A “normal” is a long term average that…',
#  "@dharinipart @jamilwest @GlobalEcoGuy This thread is worth the read:\nhttps://t.co/PVYThw4bsK\nPeople concerned about climate, which should be all of us, should begin changing their behavior as fast as they can. As well as pushing for political change. But politicians won't move till public moves (see #1 in thread).",
#  "@CaraSantaMaria Btw, there was a couple of tweets under that tweet that I forgot to tag you in to.\n\nOne includes a collection of academic papers from around the world on neoliberalism and climate change that I'd love for you to share with the guys if possible.",
#  "Today's forecast high for Bakersfield CA is 99°\nRecord high was 107° way back in 1996\nSource: MS Weather\n\nGov. Jerry Brown will never mention that. He is busy misleading the public about climate change.\n\nGov. Brown has his head up his brown!",
#  'every time i get a flood warning on my phone or it rains for an extended period of time (a week or so) i think of my 8th grade science teacher who dedicated a whole unit to climate change and told us deadass that the east coast would just be underwater in x amount of years',
#  "Actually, it DOES matter, @SecretaryZinke. About 40% of US #coal production comes from lands YOU manage. You're making #climatechange and fires worse. https://t.co/2DPVx4q7LC",
#  '@ChrisCuomo @CuomoPrimeTime , God made heaven and earth and it as good”.   Trump refuses to acknowledge climate change.  The circular arguments with those biblical quotes gets us only more frustrated as accountability lacks common sense.',
#  'RT @SwaggerScanMia: 🌇SwaggerScan’s Top 10 places for #singles to live in the U.S. https://t.co/RzkrnLguEO\n\n#bitcoin #graduation #jobsearch…',
#  "@AndyOz2 @CNN I agree with you. I don't believe in climate change, this is all scare mongering to make money. I believe the Earth goes through natural cycles &amp; there's nothing we can do about it.",
#  "RT @BlackDouglas: Let's start by banning land clearing!! https://t.co/8v0Bmr3LwM",
#  'RT @wrobertsfood: Canadian taxpayers give away millions to US pipeline owners, despite threat to #GlobalWarming and #foodsecurity https://t…',
#  '@HermanMashaba Mr mayor,  are you a climate change denier? Trump is. Do you consider SA a "shithole"? Trump does. By the way did you take notice of the deadly demonstrations in the US in Charlottesville?',
#  "RT @democracynow: Up next: We're speaking with Jesse Brucato and Sallie Holmes, two concerned Steamboat Springs, CO residents who confronte…",
#  'How would you use #Copernicus climate data and #CDS tools to inform specific sectors about the impacts of #ClimateChange? Submit a bit in our new tenders for innovative ideas (https://t.co/wSrSN7wVgu) and sustainable applications (https://t.co/GOXeHb4CVQ). First deadline 14 Sep. https://t.co/jscilqUQM1',
#  '@phbarratt Eliminate all worthwhile options and then offer something totally inadequate and then say if you don’t accept this you’ll leave us rudderless.  How did the man who vowed he would not lead a Party that didn’t believe in addressing Climate Change diminish himself to this  state.',
#  'Halfway to boiling: the city at 50C #ClimateChangeIsReal  https://t.co/1EuT9lAdZ7',
#  '@jaySA94 @swimlittlefish @KgaugeloSM @HermanMashaba Trump may be "brilliant" in your eye but perhaps you are also a bigot, climate change denialist, and believe that the best way for the US president to reveal his thoughts to the world is via Twitter. Personally I think he is a horses ass',
#  "RT @stonybrooku: .@NYSERDA has committed $20.5M to #StonyBrookU's Advanced Energy Research and Technology Center, following a $18.5M @ENERG…",
#  'MISS yesterday’s BOOMERS (c) stevenn beck, here’s “EMPTY GESTURE”\n* FOLLOW ON FB, INSTAGRAM + TWITTER!\n#stevennbeck #babyboomers #boomerscomics #sitcoms #yoga #meditation #guncontrol #peace #resist #science #globalwarming #Mindfulness https://t.co/nDmV16wz0u',
#  'RT @ClaudiaKammann: Glad to hear that there are Programms left in the US that people can watch that feed o  scientific facts actually! Watc…',
#  'By me: why climate change makes us think two impossible things at the same time before breakfast. \nhttps://t.co/0GzJrfRcyT',
#  'Instant relief operation in my hometown here in Bulacan. No one expected this to happen but praise God for all our volunteers 🙏 #climatechangeisreal #bayanihan #Vpositive https://t.co/MEW47OKuw7',
#  'Rahm Emanuel cares about illegal immigrants, climate change &amp; radical LGBT activists, but the violence &amp; chaos in the black community? Not on his radar screen because Democrats are going to get black votes regardless. https://t.co/58yScZ5pjQ',
#  "Caribbean states beg Trump to grasp climate change threat: 'War has come to us'\n#climatechange #LossAndDamage #ClimateDamagesTax \n\nhttps://t.co/neQqfxFUI6",
#  'We happily go along with blaming others for climate change. Govs blame us, cow farts and cars etc. What they do bugger all about is the 1/4 difference that can be made by stopping logging and... https://t.co/NoIzrb833d',
#  'RT @IEcologiaUNAM: En #Oikos=\nEl calentamiento global puede ser mucho más grave de lo que se ha sugerido ya que podría traer problemas de d…',
#  '@beallyryan @krelmtoothpaste Scientific reading should include the validated science of climate change. Try it.',
#  'LAST CALL: Send us your questions about #climatechange in SA 👇🏿 https://t.co/omiFkX3zmy',
#  'How can we learn to appreciate everything given to us by nature?\nhttps://t.co/I7Y5LKgxnf\n#climatechange #climateaction \n#environment \n#energy https://t.co/qQrnUXjXCM',
#  'Considering building in @lomondtrossachs? Have you thought about how your design could reduce energy demand &amp; contribute to climate change targets? 🏠 Find out more about how to consider energy conservation in your building design in our new guidance: https://t.co/yF7KluMYHB https://t.co/wy6XsqRlbu',
#  'We hope you all have a great start to the week. Our message for Monday: cherish the earth. \n\nhttps://t.co/opwA5fitt5\n\n#environment #climatechange #farmers #earth #indiefilm #documentary https://t.co/frjnzVOmCL',
#  'Trees clean air and water, slow #climatechange, ease poverty and hunger, prevent species loss, and feed the human soul. All we need to do is plant and care for them. Let’s work together to make it happen around the world. #planttrees @arborday #MondayMotivation #ClimateAction https://t.co/gFuOuu6r7Y',
#  'Free half day business training for SMEs - How to pitch for new business &amp; how to work with the public sector. Join us 4 Sep in #Thurrock. Book your place online at https://t.co/Knncb20tWy\n\n#Essex #Kent #productivity #greenbiz #renewables #sustainability #climatechange #lowcarbon https://t.co/OKK1CS0L9L',
#  'The thing about science is that it happens whether you believe in it or not.  However, believing in climate change can help us be better prepared for it and it’s effects https://t.co/ldmOzyeUkx',
#  "The dust in the wind: #Africa's efforts to restore degraded land https://t.co/qFTOYCy905 via @_AfricaTimes #climatechange https://t.co/cLqRko4693",
# ...
#  '@WhiteHouse @realDonaldTrump Great. We’ll be poor and starving and suffering from climate change, but by God, no other country is going to bother us and we’ll be safely suffering!',
#  '@Tesla @elonmusk how can you justify taking $ from Saudi Arabia who has arguably co tributes more to polluting the planet and global warming than any other country? If they want to buy on open market that’s one thing but to partner with them I just don’t get. Let them go BK selling oil!',
#  '"The next decade will almost surely decide our fate. That should empower us. It means every act has meaning; we have the chance to save the world as we know it every single day."  Indeed.  #StopKM #StopKMBuyout #KeepItInTheGround #protecttheinlet https://t.co/i0Gi3qLkM6',
#  'Global Warming is coming to kill us. \n\nFires - Floods - Hurricanes - Heat Waves - Famines - Pandemics\n\nSOLUTION:\n\n1) Fire Trump.\n\n2) Vacuum the carbon out of the air and put it back in the ground (or ocean). \n\n3) Plant trees.\n\n4) Stop polluting. https://t.co/bhINRs5ig7',
#  '@gandafdp *Realises this is just to make us forget about global warming* https://t.co/PSARTMvMvT',
#  "Oh boy. @SecretaryZinke is giving us his unscientific opinion again, with the bonus of trying to sell out our public lands to commercial logging. \n\nYES, climate change is making the fires worse. \n\nNO, commercial logging won't fix it.\n\nZinke = Charlatan.\n https://t.co/a4oRVbHA3y",
#  'If we don’t name the root cause of our ailing western #forests — #climatechange —we won’t fix the problem. That responsibility falls on all of us, including the media. Thanks \u2066@EENewsUpdates\u2069 for being on top of this issue! \u2066@AmericanForests\u2069  https://t.co/qHsskLV2Ti',
#  '#renewables #RenewableEnergy #sustainability #energy #emissions #climatechange Why are green energy not cutting emissions?  See https://t.co/AX8GfRS3mQ',
#  'To help navigate the effects of climate change on watersheds, an interdisciplinary team assessed six water basins across the US as part of a project, “Social-Ecological System Resilience, Climate Change, and Adaptive Water Governance,” funded @SESYNC https://t.co/7U4luOE1mN https://t.co/0cAw7ekZEy',
#  "@SherbertHpally @kathmandupost @bajhangimitra @hahahahalmfaooo Pay for what?\n\nCompanies are founded on exploiting their workers &amp; the world for profits. Without corporations we wouldn't have climate change, wouldn't have world hunger &amp; everyone could get healthcare &amp; a house to live in. They *should* go bankrupt, maybe we'll try communal own",
#  '@cleanenergycan The "climate strategy" is nothing more than creative socialism. With the previous Ontario govt and their support for such, one has to wonder who really destroyed businesses more - climate change OR the socialism that was predicated on climate change..... you decide.',
#  '@bkstar00 @CBSNews @RogueNASA NASA is for peace and science. Trump and the GOP want nothing to do with that. Also NASA has provided all the data to show the threat of climate change. Not something they want either.',
#  "@ChasingCoral is a fantastic documentary to watch on Netflix. Do it now! Yes, most of us know the devastation to the coral reefs out there, some don't. This is certainly eye opening and we'll documented. #Documentary #coral #conservation #MarineBiology #climatechange",
#  "'I see a clear and present danger. Our climate is changing and it will harm us all.' A warning from our Executive Director @steventrent on the urgent need to act on climate change https://t.co/4bc3ZN860A #RecogniseRights",
#  'Emily Brooks received her PhD in Anthropology from @UCIrvine in 2017. Her research explores the cultural politics of environmental problems in the US Southwest, with a focus on water scarcity and climate change. https://t.co/vtRnklMXkF',
#  'RT @CongressmanRaja: Thanks to Tom Skilling, Prof. Don Wubelles, Doug Sisterson of Argonne National Laboratory, and everyone who joined us…',
#  'The Union Speakers Forum and the School of Engineering present Climate Change: The Inescapable Math of the Planet on September 7th. https://t.co/NNYPtF4sKl',
#  '@jilevin Mr @RyanZinke, as you’re choosing to be ignorant about climate change by sharing an opinion with a tiny %% of idiot scientists, STEP DOWN NOW. Since you haven’t noticed 🌏 is in serious trouble, let’s fill your spot w/someone who does.',
#  "@BeavertonLib @CityofBeaverton @AdrianFreund I do know of something(s) that car can more effectively give people than bikes though..\n\n-Asthma\n-Obesity\n-Climate Change\n-Tramatic Death\nEtc...\n\nDisheartened that Beaverton's residents see yet another simple activity (using the library) that apparently mandates use of a car.",
#  '"Disaster can be averted though. It\'s not about doom and gloom and let\'s give up and have a beer," he said. Well... have that beer anyway.\nhttps://t.co/snnfP48ByN',
#  'Of course, that is almost always the case. If its not us its lightening strikes. https://t.co/J5NMTm9164',
#  '@Sciam:  Climate change won’t destroy the planet or make humans go extinct.  But it’s still a villain.  It shouldn’t take an apocalypse to make us do the right thing https://t.co/xGg6gIA11A',
#  '@SecretarySonny @SecretaryZinke Fossil fuels are contrib. to longer fire season: 2+ mo longer than in 70s. Our children r fighting for their lives b/c of climate change &amp; Zinke wants 2 destroy public lands for more fossil fuels? Americans want energy indep. thru renewables, not dirty FF https://t.co/Ft7L9TtHdH',
#  'RT @freddyatton: Global Warming is coming to kill us. \n\nFires - Floods - Hurricanes - Heat Waves - Famines - Pandemics\n\nSOLUTION:\n\n1) Fire…',
#  "Let's imagine...\n\nWhat narrative film would tell a story that most compellingly captures the public imagination on climate change — hits home the severity of the threat of extinction, and reminds us of the... https://t.co/qxcxa3CWuU",
#  '"4 exploitive societies that died out." https://t.co/lmxrtIdsqI &gt;@MotherNatureNet - #Sustainability #ClimateChange - "\nIf you want your way of life to come to a bitter end, follow the example of these ancient civilizations." https://t.co/ncyGBW0mI0',
#  '3 Big Problems and 1 Simple Solution:\n\nLet’s Flip Congress Blue &gt;&gt;&gt; https://t.co/hJjulqalNX 🌊 https://t.co/GyjFy3ln3H',
#  '“It is the temperature at which human cells start to cook”\nLuckily, we don’t need government officials to act on climate change to start pitching in by ending the demand for planet-boiling products: meat &amp; dairy\n#ActOnClimate #GoVegan #ShareThePlanet #WFPB https://t.co/thuz1t9yUu',
#  'RT @Doug350: https://t.co/WDaF6OTnUD - tweet @MYBW6978\n\nWOULD Y’ALL DO THE PLANET A FAVOR?\n\nTweet or RT or Reply this to @MYBW6978\n\nMother…',
#  '@Liam03996482 @veemclean1 @Danielbjones6 @slowhands27 @proud_remoaner @klalalabour @netanyahu Climate change is accepted as happening the reliance on fossil fuels. Being alive causes dying. Sld we not bother? Travel broadens the mind but jet fuel so let’s not bother. Modern medicine means people live full lives but they consume so let them die. State control won’t stop it',
#  'US interior secretary says California wildfires nothing to do with climate change https://t.co/qHOjhuQ1gR',
#  '@CNN is getting lazy with their news headlines. “If climate change continues, new data suggests our lives will become less safe.”\n\nIt’s 2018 I thought the world was gonna end 6 years ago I know my time is coming',
#  'RT @guardianeco: US interior secretary says California wildfires nothing to do with climate change https://t.co/qHOjhuQ1gR',
#  "We may be the first generation to experience the servers effects of climate change,  but we might be the last generation which can do something about it.  LET'S ACT TODAY https://t.co/WudDVfQ6Ty",
#  'RT @thenarwhalca: The latest oil and gas industry projections are incompatible with Canada’s #ParisAgreement emissions targets — so why did…',
#  'People really get paid to tell us the most common sense shit. #GlobalWarming https://t.co/Gr4WzEoEG6',
#  'A line of reporters (editors etc included) and god knows how many analysts got paid to tell us that #globalwarming (cautiously re-dubbed #climatechange) is dangerous.',
#  'RT @CottonBecs: The opening dinner of the  #cfconf2018 asked us to "question our level of ambition..."; "whether we too need to he doing mu…',
#  "@KevinMFeeney the actual problem with climate change is rapidly becoming that it's not going to kill us all anywhere near soon enough",
#  'RT @The_New_Fire: #LENR #BreakingNews 2.5 hours heat output (25+W, operation temperature 200-500°C) with zero input power! https://t.co/M2Z…',
#  'US interior secretary says California wildfires nothing to do with climate change https://t.co/p5FvTX64b4',
#  '@top25rankings Yeah I’m good. It was gone in no time. And people that think those are myths are some of the most delusional people on the planet. Especially the ones that think climate change just has to do with heat (and even then try to deny that it’s not getting warmer)',
#  'The era of megafires: the crisis facing California and what will happen next. Three scientists explain the unprecedented danger facing the western US and call for new solutions to a growing threat. https://t.co/xxQx3wNlSq',
#  'US interior secretary says California wildfires nothing to do with climate change https://t.co/Bh5zj1aYgd',
#  'Does anyone recall that the Aztec capital was built on a lake which does not exist today? Land changes nothing stays the same as evidenced by changes on our planet. Yet, the environmentalists are like still trying to stop that which is natural. Clearing debris is essential. https://t.co/nhF0xEpEbJ',
#  '🗞️ NASA Carbon Monitoring Plan Shut Down Amid Climate Change Disaster \n\nhttps://t.co/AaYI6LfqQ0  \n\nPublished on May 14, 2018@3:05pm #ValueWalk',
#  'We want out of this FAILURE of a deal! \nTime to elect new\nLeaders,who deal in\ncompetence truth,facts,\nscience,variable reality.\nWho put our shared\nhumanity first.\nWho stress compassion,\ninclusion,kindness not\nhate and division. https://t.co/Cne0PCYdrq',
#  'RT @BuildTheWave: 3 Big Problems and 1 Simple Solution:\n\nLet’s Flip Congress Blue &gt;&gt;&gt; https://t.co/hJjulqalNX 🌊 https://t.co/GyjFy3ln3H',
#  'Has California gotten hotter since you arrived? Tell us your climate change stories https://t.co/ejsww8YtqF',
#  '@thatantiwarguy @SwainLQR @mateagold @Fahrenthold @mattzap Well, combating climate change MUST take a wide number of forms, including demilitarizing to some extent and ending conflicts that exacerbate climatic destruction.',
#  'CNN: If climate change continues, new data (oooohhh 🧐 NEW DATA!) suggests our lives will become less safe. \n\nNEWSFLASH for #FakeNewsCNN: If rampant Leftism continues, particularly the compulsion to silence expression, #climatechange will be least of our concerns. It already is. https://t.co/q2VCvb3YBQ',
#  '“There can be no understanding of our current and future predicament without understanding why we failed to solve this problem when we had the chance.” via @NatObserver #climatechange https://t.co/hib4HOBBc2',
#  "Produce Prose is out! READ Today's AG News.  https://t.co/5UfQ3SoBAk Stories via @CleanerMDfarms @SUN_Movement @daiyafoods #organic #climatechange",
#  'World war prompted the UK and US to change the economy "almost overnight".\n"We know we can do that. It\'s a question of understanding this is an emergency situation." (Dr James Renwick)\nvia NZ Herald https://t.co/LHBdh8CcYC',
#  "Not to mention it's almost guaranteed to kill a heck of a lot more of us globally than terrorists https://t.co/l6fAHCVHuq",
#  "i can't wait for the events outlined in the documentary film '2012,' starring John Cusack, to come true so I can push Zinke out of the way as I board the vessels saving humanity from global catastrophes and watch as he and his colleagues suffer as a result of their stupdity https://t.co/x2n45GwWLE",
#  'Driving through Pennsylvania I saw a river completely flooded and flooded into a farm ruining crops and homes... these storms dumping rain are detrimental to not only wildlife but also us. Climate change isn’t a joke.',
#  'US interior secretary says California wildfires nothing to do with climate change https://t.co/qCjWKcSUxl https://t.co/PplbDtJOz3',
#  'People need to be more aware of this. We cannot combat climate change without facts, science, perspective and political muscle. https://t.co/FVO0JoPcsj',
#  "A common boogeyman today is the fossil-fuel industry, but it didn't truly start efforts to confuse the public about #climatechange until 1989. So, what else went wrong? https://t.co/n4D4etbbzy via @NatObserver",
#  '@SenSanders As if humans can really do anything about climate change. The earth, sun, and nature are a lot bigger than us.',
#  'US interior secretary says California wildfires nothing to do with climate change https://t.co/Ap6S5lxZDI',
#  'US interior secretary says California wildfires nothing ot do wtih climate change https://t.co/YllgWesAXr',
#  'RT @guardian: US interior secretary says California wildfires nothing to do with climate change https://t.co/Ap6S5lxZDI',
#  'US interior secretary says California wildfires nothing to do with climate change https://t.co/ufZ7CWwqmt',
#  'US interior secretary says California wildfires nothing to do with climate change https://t.co/ZlryvR0uNC',
#  'It’s now confirmed another uninformed dolt is on Trump’s cabinet. Everyone must must vote Trump out of office! https://t.co/fo7nWJVbJc',
#  '@Tangomitteckel @EthonRaptor @PMS280153 @adviseagainstit @kmpClimate @FraserMacLeod5 @JPolov @bjjuhl58 @Michael_D_Crow @brandonrgates @redforged42 @douglast29347 @jamieswilson @StormSignalSA @Blind_Populous @Pandeism @swcrisis @donnoble63 @ClimateCatastr1 @climatefrauds @Gladfly1 @Canberroo @JaggerMickOZ @vincent_philion @1_TMF_ @PolAnimalAus @Zerilos @tjtjgeol @vanvlietdesign @Tokyo_Tom @GillesnFio @WallaceWestland @Wild_Willdy @caerbannog666 @wildweatherdan @BradSchrag @NikolovScience @geoffmprice @Camburnclimate @mccaffreydanie1 @LeeWheelbarger @TannedBeach @craigthomler @AtomsksSanakan @RogTallbloke @Ike_Kiefer @Ceist8 @EC_Kosters @SturmLLiouville @SafariWoman "Therefore, global warming is making earth temperature more stable!"\n\n*shakes head*\n\nThe quality of scientific discourse from denialists is dreadful.',
#  'US interior secretary says California wildfires nothing to do with climate change https://t.co/5n1sz0IPJt',
#  'US interior secretary says California wildfires nothing to do with climate change https://t.co/EiToXR3kJm | The Guardian',
#  'RT @GuardianUS: US interior secretary says California wildfires nothing to do with climate change https://t.co/ZlryvR0uNC',
#  'Heat waves are among the deadliest weather-related events in the US. Read @UCSUSA’s new fact sheets to learn about the risks from extreme heat and the science connecting it to climate change https://t.co/6dfkxcBjUj',
#  'US interior secretary says California wildfires nothing to do with climate change https://t.co/xRigVZuca0',
#  "Well, now that is settled, let's cut down all the trees and pollute all the water! SMH\n#StinkyZinke\n\nhttps://t.co/eg7dpd7pSA",
#  'RT @guardian: US interior secretary says California wildfires nothing to do with climate change https://t.co/xRigVZuca0',
#  'Stunning idiocy. https://t.co/SbBkdg2fat',
#  "Leaving the US is a self defense move #FreeCalifornia #FreeTheBear\nZinke on California fires: 'This is not a debate about climate change' https://t.co/zUpqFsgEST",
#  '#Oceanography #ClimateChange : Scientists trace atmospheric rise in CO2 during deglaciation to deep Pacific Ocean. What concerns the researchers is that a similar phenomenon could happen again as the climate continues to warm - https://t.co/gwmgtTECr6 https://t.co/RccB5vq8RH',
#  'RT @ClimateCg2018: #ClimateChangeconference #MeetingsInt #climatecg2018\nJoin Us at World Summit of Climate Change &amp; Global Warming at Tokyo…',
#  ...]
